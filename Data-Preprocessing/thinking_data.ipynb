# %%
import json

# %%
#load the data
def load_data(filename):
    with open(filename,"r") as f:
        data=json.load(f)
    return data

# %%
data=load_data("store_data.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Ayushi', 'rating': '5', 'feedback': 'good Quality!', 'age': '22'}, {'name': 'Rahul', 'rating': 'four', 'feedback': 'Very useful product', 'age': '24'}, {'name': 'Sneha', 'rating': '5', 'feedback': 'Excellent service', 'age': '21'}, {'name': 'Sweata', 'rating': '3', 'feedback': 'Good', 'age': '28'}]
# <class 'list'>

# %%
#Clean and structure the data
def clean_data(data):
    text_to_num={"one":1,"two":2,"three":3,"four":4,"five":5}
    cleaned_data=[]
    unique_users=set()

    for user in data:
        #clean ratings
        raw_rating=str(user["rating"]).strip().lower()
        if(raw_rating in text_to_num):
         raw_rating=text_to_num[raw_rating]
        user["rating"]=raw_rating
         


        #Handle missing vals
        #Earlier age key doesn't exist but age key is added with null value now
        raw_age=user.get("age")
        if(raw_age == None):
            user["age"] = None

        #Deduplication
        if(user["name"].strip() in unique_users):
            continue

        unique_users.add(user["name"])
        cleaned_data.append(user)

    return cleaned_data

# %%
data=clean_data(data)

# %%
#Getting meaningful insights from the data

def get_insights(data):

    #avg_rating
    tot_rating=0
    for user in data:
        tot_rating+=float(user["rating"])
    print(f"Average rating is {tot_rating/len(data)}")
          
    # % of users with poor rating
    poor_ratings=0
    for user in data:
        if(float(user["rating"])<3):
            poor_ratings+=1

    print(f"% of user with poor rating is {poor_ratings/len(data)*100}%")

# %%
get_insights(data)
# Out:
# Average rating is 4.25
# % of user with poor rating is 0.0%

# %%
#Build recommendation Feature
def get_recommendations(data):
    recommendation=[]

    for user in data:
        curr_recomm={}
        curr_recomm["name"]=user["name"]

        if(float(user["rating"])>=4):
            curr_recomm["brand"]="Apple"
        else:
            curr_recomm["brand"]="Samsung"
        recommendation.append(curr_recomm)
    return recommendation

# %%
get_recommendations(data)
# Out:
# [{'name': 'Ayushi', 'brand': 'Apple'},
#  {'name': 'Rahul', 'brand': 'Apple'},
#  {'name': 'Sneha', 'brand': 'Apple'},
#  {'name': 'Sweata', 'brand': 'Samsung'}]
